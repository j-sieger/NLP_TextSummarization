# %% [markdown]
# # Abstractive Text Summarizor

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#Change the working directory
import os
import gc
os.chdir('/content/gdrive/My Drive/Colab Notebooks/NLP/Text Summarization/Abstractive Text Summarization')
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
os.listdir()
# Out:
# ['Dataset', 'attention.py', 'Abstractive Text Summarization.ipynb']

# %%
from attention import AttentionLayer

# %%
import numpy as np
import pandas as pd 
import re
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
import nltk
from nltk.corpus import stopwords
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
reviews_dataset = pd.read_csv("Dataset/Food Reviews.csv")
reviews_dataset.head()
# Out:
#    Id  ...                                                                                                                                                                                                     Text
# 0   1  ...  I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labr...
# 1   2  ...           Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# 2   3  ...  This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with ...
# 3   4  ...  If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The fl...
# 4   5  ...                                                             Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
#
# [5 rows x 10 columns]

# %% [markdown]
# ## Drop Duplicates and NA values

# %%
reviews_dataset.drop_duplicates(subset=['Text'],inplace=True)#dropping duplicates
reviews_dataset.dropna(axis=0,inplace=True)#dropping na

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# We will perform the below preprocessing tasks for our data:
#
# 1.Convert everything to lowercase
#
# 2.Remove HTML tags
#
# 3.Contraction mapping
#
# 4.Remove (‘s)
#
# 5.Remove any text inside the parenthesis ( )
#
# 6.Eliminate punctuations and special characters
#
# 7.Remove stopwords
#
# 8.Remove short words

# %%
# Removing Contractions
contractions = {"ain't": "is not", 
                       "aren't": "are not",
                       "can't": "cannot", 
                       "'cause": "because", 
                       "could've": "could have", 
                       "couldn't": "could not",
                       "didn't": "did not",  
                       "doesn't": "does not", 
                       "don't": "do not", 
                       "hadn't": "had not", 
                       "hasn't": "has not", 
                       "haven't": "have not",
                       "he'd": "he would",
                       "he'll": "he will", 
                       "he's": "he is", 
                       "how'd": "how did", 
                       "how'd'y": "how do you", 
                       "how'll": "how will", 
                       "how's": "how is",
                       "I'd": "I would", 
                       "I'd've": "I would have", 
                       "I'll": "I will", 
                       "I'll've": "I will have",
                       "I'm": "I am", 
                       "I've": "I have", 
                       "i'd": "i would",
                       "i'd've": "i would have", 
                       "i'll": "i will",  
                       "i'll've": "i will have",
                       "i'm": "i am", 
                       "i've": "i have", 
                       "isn't": "is not", 
                       "it'd": "it would",
                       "it'd've": "it would have", 
                       "it'll": "it will", 
                       "it'll've": "it will have",
                       "it's": "it is", 
                       "let's": "let us", 
                       "ma'am": "madam",
                       "mayn't": "may not", 
                       "might've": "might have",
                       "mightn't": "might not",
                       "mightn't've": "might not have", 
                       "must've": "must have",
                       "mustn't": "must not", 
                       "mustn't've": "must not have", 
                       "needn't": "need not", 
                       "needn't've": "need not have",
                       "o'clock": "of the clock",
                       "oughtn't": "ought not", 
                       "oughtn't've": "ought not have", 
                       "shan't": "shall not", 
                       "sha'n't": "shall not", 
                       "shan't've": "shall not have",
                       "she'd": "she would", 
                       "she'd've": "she would have", 
                       "she'll": "she will", 
                       "she'll've": "she will have", 
                       "she's": "she is",
                       "should've": "should have", 
                       "shouldn't": "should not", 
                       "shouldn't've": "should not have", 
                       "so've": "so have",
                       "so's": "so as",
                       "this's": "this is",
                       "that'd": "that would", 
                       "that'd've": "that would have", 
                       "that's": "that is", 
                       "there'd": "there would",
                       "there'd've": "there would have", 
                       "there's": "there is", 
                       "here's": "here is",
                       "they'd": "they would", 
                       "they'd've": "they would have",
                       "they'll": "they will", 
                       "they'll've": "they will have", 
                       "they're": "they are", 
                       "they've": "they have", 
                       "to've": "to have",
                       "wasn't": "was not", 
                       "we'd": "we would", 
                       "we'd've": "we would have", 
                       "we'll": "we will", 
                       "we'll've": "we will have", 
                       "we're": "we are",
                       "we've": "we have", 
                       "weren't": "were not", 
                       "what'll": "what will", 
                       "what'll've": "what will have", 
                       "what're": "what are",
                       "what's": "what is", 
                       "what've": "what have", 
                       "when's": "when is", 
                       "when've": "when have", 
                       "where'd": "where did", 
                       "where's": "where is",
                       "where've": "where have", 
                       "who'll": "who will", 
                       "who'll've": "who will have", 
                       "who's": "who is", 
                       "who've": "who have",
                       "why's": "why is", 
                       "why've": "why have", 
                       "will've": "will have", 
                       "won't": "will not", 
                       "won't've": "will not have",
                       "would've": "would have", 
                       "wouldn't": "would not", 
                       "wouldn't've": "would not have", 
                       "y'all": "you all",
                       "y'all'd": "you all would",
                       "y'all'd've": "you all would have",
                       "y'all're": "you all are",
                       "y'all've": "you all have",
                       "you'd": "you would", 
                       "you'd've": "you would have", 
                       "you'll": "you will", 
                       "you'll've": "you will have",
                       "you're": "you are", 
                       "you've": "you have"}

# %%
def remove_contractions(text):
    text = text.split()
    new_text = []
    for word in text:
        if word in contractions:
            new_text.append(contractions[word])
        else:
            new_text.append(word)
    text = " ".join(new_text)
    return text

# %%
#We must get the values in lower case before calling remove_contraction method
reviews_dataset['Cleaned_Text'] = reviews_dataset.Text.str.lower().apply(lambda x: remove_contractions(x))
reviews_dataset['Cleaned_Summary'] = reviews_dataset.Summary.str.lower().apply(lambda x: remove_contractions(x))
reviews_dataset.head()
# Out:
#    Id  ...        Cleaned_Summary
# 0   1  ...  good quality dog food
# 1   2  ...      not as advertised
# 2   3  ...  "delight" says it all
# 3   4  ...         cough medicine
# 4   5  ...            great taffy
#
# [5 rows x 12 columns]

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 

def text_cleaner(text,num):
    newString = text.lower()
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#call the function
cleaned_text = []
for text in reviews_dataset.Cleaned_Text:
    cleaned_text.append(text_cleaner(text,0))
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
#call the function
cleaned_summary = []
for t in reviews_dataset.Cleaned_Summary:
    cleaned_summary.append(text_cleaner(t,1))
cleaned_summary[:10]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food']

# %%
reviews_dataset['cleaned_text'] = cleaned_text
reviews_dataset['cleaned_summary'] = cleaned_summary

# %% [markdown]
# ## Drop empty rows

# %%
reviews_dataset.isnull().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Summary                   0
# Text                      0
# Cleaned_Text              0
# Cleaned_Summary           0
# cleaned_text              0
# cleaned_summary           0
# dtype: int64

# %% [markdown]
# There are no NaN in the dataset

# %% [markdown]
# ## Understanding the distribution of the sequences

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in reviews_dataset['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in reviews_dataset['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %% [markdown]
# We shall consider max length for Reviews as 30 words and for summary as 8 words

# %%
count=0
for i in reviews_dataset['cleaned_summary']:
    if(len(i.split())<=8):
        count = count+1
print(count/len(reviews_dataset['cleaned_summary']))
# Out:
# 0.9458310571316046

# %% [markdown]
# 94.5% summary is covered within 8 words. So, we are good to go

# %%
max_text_len=30
max_summary_len=8

# %%
cleaned_text = np.array(reviews_dataset['cleaned_text'])
cleaned_summary = np.array(reviews_dataset['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split()) <= max_summary_len and len(cleaned_text[i].split()) <= max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
reviews_dataset  = pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
reviews_dataset['summary'] = reviews_dataset['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %% [markdown]
# ## Split the dataset into train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_validate, y_train, y_validate = train_test_split(np.array(reviews_dataset['text']), np.array(reviews_dataset['summary']),test_size = 0.1,random_state = 3, \
                                                            shuffle = True)

# %% [markdown]
# ## Text Tokenizer

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_train))

# %% [markdown]
# ## Rarewords and its Coverage

# %%
thresh = 2

cnt = 0
tot_cnt = 0
freq = 0
tot_freq = 0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt = tot_cnt + 1
    tot_freq = tot_freq + value
    if(value < thresh):
        cnt = cnt + 1
        freq = freq + value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 46.83973818415452
# Total Coverage of rare words: 0.6802727039447594

# %% [markdown]
# ## Text to Sequence and Padding

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words = tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_train))

#convert text sequences into integer sequences
x_train_seq    =   x_tokenizer.texts_to_sequences(x_train) 
x_validate_seq   =   x_tokenizer.texts_to_sequences(x_validate)

#padding zero upto maximum length
x_train    =   pad_sequences(x_train_seq,  maxlen = max_text_len, padding = 'post')
x_validate   =   pad_sequences(x_validate_seq, maxlen = max_text_len, padding = 'post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

x_voc
# Out:
# 26478

# %% [markdown]
# ## Summary Tokenizer

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_train))

# %% [markdown]
# ## Rarewords and its Coverage

# %%
thresh = 8

cnt = 0
tot_cnt = 0
freq = 0
tot_freq = 0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt = tot_cnt + 1
    tot_freq = tot_freq + value
    if(value < thresh):
        cnt = cnt+1
        freq = freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 79.94533652203621
# Total Coverage of rare words: 3.133851110624173

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words = tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_train))

#convert text sequences into integer sequences
y_train_seq    =   y_tokenizer.texts_to_sequences(y_train) 
y_validate_seq   =   y_tokenizer.texts_to_sequences(y_validate) 

#padding zero upto maximum length
y_train    =   pad_sequences(y_train_seq, maxlen = max_summary_len, padding = 'post')
y_validate   =   pad_sequences(y_validate_seq, maxlen = max_summary_len, padding = 'post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

# %%
y_tokenizer.word_counts['sostok'],len(y_train)
# Out:
# (189227, 189227)

# %%
ind=[]
for i in range(len(y_train)):
    cnt=0
    for j in y_train[i]:
        if j != 0:
            cnt = cnt+1
    if(cnt == 2):
        ind.append(i)

y_train = np.delete(y_train, ind, axis = 0)
x_train = np.delete(x_train, ind, axis = 0)

# %%
ind=[]
for i in range(len(y_validate)):
    cnt = 0
    for j in y_validate[i]:
        if j != 0:
            cnt = cnt+1
    if(cnt == 2):
        ind.append(i)

y_validate = np.delete(y_validate,ind, axis=0)
x_validate = np.delete(x_validate,ind, axis=0)

# %% [markdown]
# ## Model building

# %%
backend.clear_session()
tf.reset_default_graph()

# %%
latent_dim = 300
embedding_dim = 100
batchsize = 128

# %%
# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim, trainable = True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim, return_sequences = True, return_state = True, dropout = 0.2, recurrent_dropout = 0.2)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim, return_sequences = True, return_state = True, dropout = 0.2, recurrent_dropout = 0.2)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3 = LSTM(latent_dim, return_state = True, return_sequences = True, dropout = 0.2, recurrent_dropout = 0.2)
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape = (None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences = True, return_state=True,dropout = 0.2, recurrent_dropout = 0.2)
decoder_outputs, decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state = [state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name = 'attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis = -1, name = 'concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation = 'softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 100)      2647800     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 30, 300), (N 481200      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 30, 300), (N 721200      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    411000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 30, 300), (N 721200      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 300),  481200      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 300),  180300      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 600)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 4110)   2470110     concat_layer[0][0]
# ==================================================================================================
# Total params: 8,114,010
# Trainable params: 8,114,010
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = 'rmsprop', loss = 'sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 2)

# %%
history = model.fit([x_train, y_train[:,:-1]], y_train.reshape(y_train.shape[0], y_train.shape[1], 1)[:,1:], epochs = 20, callbacks = [es], batch_size = batchsize, \
                  validation_data = ([x_validate, y_validate[:,:-1]], y_validate.reshape(y_validate.shape[0], y_validate.shape[1], 1)[:,1:]))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 185743 samples, validate on 20618 samples
# Epoch 1/20
#   2176/185743 [..............................] - ETA: 17:18 - loss: 4.3686

# %% [markdown]
# ## Understanding the Diagnostic plot

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label = 'train')
pyplot.plot(history.history['val_loss'], label = 'test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Next, let’s build the dictionary to convert the index to word for target and source vocabulary:

# %%
reverse_target_word_index = y_tokenizer.index_word
reverse_source_word_index = x_tokenizer.index_word
target_word_index = y_tokenizer.word_index

# %% [markdown]
# ## Inference

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs = encoder_inputs, outputs = [encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape = (latent_dim,))
decoder_state_input_c = Input(shape = (latent_dim,))
decoder_hidden_state_input = Input(shape = (max_text_len, latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2 = dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state = [decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis = -1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input, decoder_state_input_h, decoder_state_input_c], 
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    encoder_out, encoder_h, encoder_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [encoder_out, encoder_h, encoder_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len - 1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        encoder_h, encoder_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString = ''
    for i in input_seq:
        if((i != 0 and i != target_word_index['sostok']) and i != target_word_index['eostok']):
            newString = newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString = ''
    for i in input_seq:
        if(i != 0):
            newString = newString + reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_validate[i]))
    print("Original summary:", seq2summary(y_validate[i]))
    print("Predicted summary:", decode_sequence(x_validate[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: product tastes good developed issues soy allergy see information provided wanted let others know
# Original summary: good product contains soy
# Predicted summary:  great product
#
#
# Review: availible local market happy find brand quality
# Original summary: delicous
# Predicted summary:  great
#
#
# Review: absolutely love company ordered twice never problem ship fast love actually ordering week use pink salt bath salts sell sample salts tried excellent one favorite
# Original summary: excellent product
# Predicted summary:  love this salt
#
#
# Review: kids love great tasting easy fix highly recommend busy parent lots great things healthy kids
# Original summary: so easy and so good
# Predicted summary:  great for kids
#
#
# Review: truvia tastes like sugar without aftertaste happy able find large sized quantity shipped quickly totally satisfied easily available elsewhere
# Original summary: excellent product in large sized package
# Predicted summary:  great product
#
#
# Review: good garden greens baby purees organic without sweet like packaging design well great go highly recommended
# Original summary: fresh and healthy
# Predicted summary:  good for baby
#
#
# Review: delicious sweet spicy tea big tea drinker drink tea tea nearly every day
# Original summary: love this tea
# Predicted summary:  delicious
#
#
# Review: influenster quaker sent cookie try looked delicious healthy never know delighted good great tasting love
# Original summary: love this cookie
# Predicted summary:  quaker soft baked oatmeal cookie
#
#
# Review: jelly beans wonderful different flavors shapes perfect affect wonderful flavors good buy
# Original summary: does not matter
# Predicted summary:  jelly beans
#
#
# Review: love goji berries especially chocolate covered ones best ever tasted goji berries plump moist
# Original summary: excellent
# Predicted summary:  goji berries
#
#
# Review: love tazo teas dont really like ones one okay tart sweeten one ove favs
# Original summary: great tasting
# Predicted summary:  love this tea
#
#
# Review: sweetly filling two per package br br ordering
# Original summary: valley of health
# Predicted summary:  great
#
#
# Review: comes lovely little packets great portion control definately tastes better dark chocolate cocoa great value
# Original summary: dark chocolate is good for you right
# Predicted summary:  great cocoa
#
#
# Review: drawback receiving one packet include dietary information expected tastes good time would liked information determine would fit well health plan without information would reluctant order
# Original summary: received one packet for review tastes good
# Predicted summary:  great product
#
#
# Review: cups look different taste normal keurig cups without extra plastic recycle alarmed opened box cups fit work well keurig brewer
# Original summary: different cup same coffe
# Predicted summary:  cup of coffee
#
#
# Review: arrived promised damage box contents delicious bars great price offered office great fundraiser
# Original summary: yum
# Predicted summary:  great
#
#
# Review: wish never bought brand darrell lea way better tasting expiration date longer comes australia
# Original summary: bad mistake
# Predicted summary:  best ever
#
#
# Review: stuff rocks long time fan regular walker shortbread tastes even better better texture like regular shortbread definitely try
# Original summary: awesome shortbread
# Predicted summary:  best gf cookies ever
#
#
# Review: love got collection coffee new machine one best love cup coffee taste bean still smooth burnt tasting load sugar take bitterness away love
# Original summary: smooth and bold
# Predicted summary:  great coffee
#
#
# Review: bought make mac cheese recipie restaurant though tasted okay maybe little oily side obviously good fresh priced right make
# Original summary: not bad
# Predicted summary:  not bad
#
#
# Review: tried many tazo similar stronger lotus one thing keep mind let sit otherwise becomes strong next time add water flavor bland
# Original summary: mm
# Predicted summary:  not my favorite
#
#
# Review: currently become favorite type tea really like barley like flavor sometimes like drinking want taste something water want drink something much sugar juice drink
# Original summary: nice tea
# Predicted summary:  great tea
#
#
# Review: one prefer juice taste like fresh squeezed love grapefruit juice nothing added basic juice except water little juice canned taste rather like fresh words love stuff
# Original summary: great juice
# Predicted summary:  juice
#
#
# Review: absolutely love selection got definitley order fabulous way try new flavors without buy whole box one flavor got several different brands several different flavors couple duplicates whole bag love
# Original summary: love this selection
# Predicted summary:  delicious
#
#
# Review: great baby loves pick bag give right size small big little guy wish company could come kind quality control gerber yogurt melts consistent prefer vitamins gerber
# Original summary: but have to pick through the sizes
# Predicted summary:  great baby food
#
#
# Review: happy coffee many brands puts coffee tired maxwell house folgers brand good coffee morning bitterness comes good every time think price reasonable
# Original summary: excellent
# Predicted summary:  great coffee
#
#
# Review: wife fond chocolate covered cherries tried every brand assures best ever eaten
# Original summary: chocolate heaven
# Predicted summary:  best cherries ever
#
#
# Review: crepe bonsai never flowered grow left outside specified instructions lost leaves probably make thru winter
# Original summary: st at bonsai
# Predicted summary:  bonsai tree
#
#
# Review: love product make often efficient alternative minute cooking time place oat stick cinnamon liquid crockpot bed hot ready eat morning
# Original summary: cook over night in
# Predicted summary:  great product
#
#
# Review: taste like earl grey tasted like kind bad lemon tea bad english breakfast bad enough want keep
# Original summary: bad lemon tea
# Predicted summary:  not as good as expected
#
#
# Review: love pina coladas able drink years fattening tried baja bob mix find bad bit different taste nothing offensive used malibu coconut rum
# Original summary: not bad
# Predicted summary:  not bad
#
#
# Review: dog loves mix dry food smell bit thats ok great price
# Original summary: good stuff
# Predicted summary:  dog loves it
#
#
# Review: crackers best crackers ever tasted eat everyday snacks like get health food stores amazon
# Original summary: crackers
# Predicted summary:  crackers
#
#
# Review: little runny side think twins bit older understand eat container bit better matter runny
# Original summary: twins love them
# Predicted summary:  not bad
#
#
# Review: got local health food store paid approx per pack little girl likes cute bear shapes like organic sweet amazon better price item
# Original summary: my yr old likes it
# Predicted summary:  great price
#
#
# Review: great product difficult find local stores carried many merchants natural product help digestion
# Original summary: tea for natural
# Predicted summary:  great product
#
#
# Review: great basket price gave doctor delivered baby impressed
# Original summary: great basket
# Predicted summary:  great
#
#
# Review: buy mine easy quick lunch little salty still like
# Original summary: very easy lunch
# Predicted summary:  good
#
#
# Review: using vanilla flavored around six weeks sweeten coffee works much better splenda left sugar cravings upset stomach say acquired taste though sweet bitter undertone little hard get used
# Original summary: little goes long way
# Predicted summary:  not for me
#
#
# Review: huge coffee drinker think really good coffee taste really smooth
# Original summary: delicious
# Predicted summary:  great coffee
#
#
# Review: crap br spend bucks buy different coffee bean direct like href http www amazon com gp product french roast whole bean coffee pound bag
# Original summary: dont buy
# Predicted summary:  coffee
#
#
# Review: decided try place expensive versions loved go back old coffee fresh delicious cheaper yay
# Original summary: yumm love this coffe
# Predicted summary:  yummy
#
#
# Review: tell anybody sugar secret worlds best chocolate chip cookies use favorite recipe watch everybody struggle figure makes awsome
# Original summary: it secret
# Predicted summary:  best cookies ever
#
#
# Review: love tasty healthy munchies keep craving unhealthy chips spicy flavor little crunch treat
# Original summary: love the little spicy munchies
# Predicted summary:  great snack
#
#
# Review: great smack especially low carb diet crunchy bit salty perfect chip alternative use instead popcorn dipping
# Original summary: awesome crunchy little
# Predicted summary:  great taste
#
#
# Review: glad annie came gluten free version bunny cookies taste great one kids favorites good price amazon
# Original summary: great price delicious gluten free cookies
# Predicted summary:  great cookies
#
#
# Review: funny hah hah funny peculiar stuff tastes old rancid like oil sat around long expired taste funny putting yogurt might mask taste like begin br br go trouble returning ordering
# Original summary: tastes funny
# Predicted summary:  horrible
#
#
# Review: amazon great br wow br super looking br recommend product hot horseradish lover br prime rib last sunday brunch br stuff hot better atomic customer life
# Original summary: com
# Predicted summary:  great hot sauce
#
#
# Review: coffee cup know cup completely empty done grinds bother much fact little coffee flavor said enjoy taste rather good instant hot chocolate
# Original summary: more of hot chocolate
# Predicted summary:  not good
#
#
# Review: found pods best tasting pods senseo coffee pod machine pods strong enough add milk coffee needs strong gave stars pods little bigger excess paper around squeeze pod holder
# Original summary: best replacement for senseo
# Predicted summary:  good coffee
#
#
# Review: fun unique birthday treat five year old daughter shared class everyone loved
# Original summary: great birthday treat
# Predicted summary:  fun
#
#
# Review: searched product happy works perfectly saves lot work time
# Original summary: litter pan for cats
# Predicted summary:  great product
#
#
# Review: year old saint bernard moving around like puppy see notable difference since started eating breeders choice active care foods could pleased
# Original summary: excellent food for large with joint problems
# Predicted summary:  great for training
#
#
# Review: terrible popcorn taste poor popping ratio size omg popped gourmet popping corn front party everyone busted laughter
# Original summary: poor product
# Predicted summary:  stale popcorn
#
#
# Review: thanks amazon able purchase regular automatic shipment excellent bread mestemacher bakery goods already knew germany bread brings exact taste back living europe bread moist grains wonderful taste simply good bread
# Original summary: three grain black bread
# Predicted summary:  pamela bread mix
#
#
# Review: like perfect spicy bloody mary mix must try make blush perfect addition summer brunch flavor great
# Original summary: indeed
# Predicted summary:  great salsa
#
#
# Review: stuff fantastic use nearly baking sweetener famous mayan hot chocolate amazon subscribe save get discount buying way crazy thing though less price local retailer even without discount
# Original summary: one of my favorite sweeteners
# Predicted summary:  best sugar free chocolate
#
#
# Review: daughter brought back germany thought big deal bit head first hippo hooked may favorite candy hands live rural area begged international shop miles away order know get amazon look
# Original summary: could not believe it
# Predicted summary:  love these
#
#
# Review: apple chips delicious relatively nutritious kids love granny smith sour varieties
# Original summary: great product
# Predicted summary:  delicious
#
#
# Review: every member family loves brownies pan gone even cool sure spray pan adding batter
# Original summary: yummy
# Predicted summary:  great brownies
#
#
# Review: buy many every year give associates christmas everyone loves including top problems order shipper right top correcting always amazon vendors best
# Original summary: next best to homemade
# Predicted summary:  great product
#
#
# Review: like little honey coffee clover honey like best great full taste sweet clear love
# Original summary: thanks mr
# Predicted summary:  best honey ever
#
#
# Review: puppy loves treats great alternative soft treats however sometimes chew completely cough treats give many drink water solves issue might want keep soft treats hand treat dog walks exercise
# Original summary: make sure your dog chews
# Predicted summary:  great treat
#
#
# Review: finally decaf kuerig good order pack much happier brand getting amazon nice medium flavor taste brand shows coffee maker best
# Original summary: best decaf
# Predicted summary:  decaf coffee
#
#
# Review: followed instructions one mushroom grew first round whole log turned moldy could try second round
# Original summary: got only one
# Predicted summary:  do not buy
#
#
# Review: looking gluten free granola bar found one tastes great
# Original summary: free
# Predicted summary:  great granola
#
#
# Review: hoping sugar free version popular purple grape sodas traditional big purple grape taste soda nice overly sweet flavor grape
# Original summary: good but not great
# Predicted summary:  not as good as the
#
#
# Review: best price found coconut oil love using cooking good also use skin makes skin soft rub little greasy minutes worth
# Original summary: best price for coconut oil
# Predicted summary:  great product
#
#
# Review: variety pack shipped freshman son college looked like good healthy snack called tell arrived loves flavors favorite apple cinnamon called applemon requested
# Original summary: college son loves them
# Predicted summary:  great snack
#
#
# Review: nutritionist put lovin ever since great snack healthy try love trader joe carries along stores amazon greater value
# Original summary: you have got to try these
# Predicted summary:  love these
#
#
# Review: easy mix morning makes great pancakes waffles like add little vanilla extract different spices change good adding fruit chocolate chips
# Original summary: quick and tasty
# Predicted summary:  great mix
#
#
# Review: good product particularly like crust use pizza stone directions easy follow served friends impressed would recommend product anyone looking good tasting good texture pizza crust easy make
# Original summary: great product
# Predicted summary:  good pizza crust
#
#
# Review: wanted like product trying eliminate splenda diet hoping would something could use unfortunately like tastes like alka seltzer flavorings thrown
# Original summary: wish did
# Predicted summary:  not good
#
#
# Review: family devoured batch buying taste nutty chocolatey protein stop afternoon hunger pangs quibble local store selling buying cannot get locally well worth getting yummy
# Original summary: love them
# Predicted summary:  delicious
#
#
# Review: awesomely soft cookie totaly love would advise anyone try would even think oats
# Original summary: quaker soft baked oatmeal cookie raisins ounce
# Predicted summary:  best cookie ever
#
#
# Review: great product received quickly problems would buy try good stuff
# Original summary: house
# Predicted summary:  great product
#
#
# Review: product well worth money make gallon tea day nice find big bags
# Original summary: great
# Predicted summary:  tea
#
#
# Review: purchased twice love gum far better market taste health wise
# Original summary: great product
# Predicted summary:  great gum
#
#
# Review: give stars favorite cups tried trust tried lot like mild coffee love one
# Original summary: green mountain coffee keurig breakfast blend
# Predicted summary:  my favorite coffee
#
#
# Review: think kraft spaghetti great kids never also liked great price free shipping ordering br thank br julie
# Original summary: kraft tangy italian spaghetti dinner
# Predicted summary:  great
#
#
# Review: bought mom coffee addict positive things say flavor however reccomend buying variety unless course mind one flavor nothing like stocking good thing
# Original summary: keurig review
# Predicted summary:  great variety
#
#
# Review: first bag tried sure healthy little snack grow taste little give know reaching another healthy label numbers real low good thing
# Original summary: healthy and tastey too
# Predicted summary:  great snack
#
#
# Review: discovered wonderfully satisfying product accident visit israel ordering ever since amazon com
# Original summary: at last great instant coffee
# Predicted summary:  great
#
#
# Review: really like cup flavor natural right sure seems fresh exactly described sweet intense apple flavor touch cinnamon
# Original summary: tasty cup of cider
# Predicted summary:  great flavor
#
#
# Review: use cup stone cone filter degree fresh filtered water good anything imo tried many private small plantation stuff good times money coffee columbian best highly recommended
# Original summary: love these
# Predicted summary:  good coffee
#
#
# Review: used seasoning past year adds zip lots flavor baby back ribs chicken jambalaya eggs etc enjoy wonderful balance herbs inspire tastebuds experience robust wonderful flavors unleashed anything like
# Original summary: the complete seasoning
# Predicted summary:  great seasoning
#
#
# Review: quick tastey break day work fits pocket dangerously delicious treat caffene jolt
# Original summary: better than coffee break
# Predicted summary:  delicious
#
#
# Review: high quality treat definitely worth price br dog even taste treats goes crazy
# Original summary: dog loves them
# Predicted summary:  my dog loves these
#
#
# Review: cups filled maybe way coffee tastes watery terrible disappointed product
# Original summary: grove square cups
# Predicted summary:  awful
#
#
# Review: product great price free shipping came timely fashon damaged
# Original summary: yogi tea
# Predicted summary:  great product
#
#
# Review: great cereal really hits spot great something easy prepare taste good
# Original summary: arrowhead mills puffed rice
# Predicted summary:  great cereal
#
#
# Review: best meatloaf mix every put market secret mix milk rather water family love
# Original summary: best mix ever
# Predicted summary:  best mix ever
#
#
# Review: bread looks like cardboard tastes like guess miss white bread stuff really edible used eating kind stuff
# Original summary: gross
# Predicted summary:  not good
#
#
# Review: far best microwave popcorn ever kinda hard find store got amazon enough popcorn last months happy product
# Original summary: you gotta get some of this
# Predicted summary:  best popcorn ever
#
#
# Review: easy go typically make food little one makes easy running errands baby loves
# Original summary: great product good food
# Predicted summary:  great for baby food
#
#
# Review: love gummy candies perfect great fruit flavor artificial nice chewy consistency
# Original summary: beat gummy candy ever
# Predicted summary:  yummy
#
#
# Review: friend come stay us week found ate gluten free days arrived quickly got onto amazon found various products thought worth giving try loved cookies thank unfortunately get eat many loved
# Original summary: cookies
# Predicted summary:  great gluten free brownies
#
#
# Review: wellness complete health dry food salmon deboned turkey food make cat sick super stinky loves
# Original summary: cat loves it
# Predicted summary:  my cats love this food
#
#
# Review: give cats whenever travel really seem help time use
# Original summary: seems to work
# Predicted summary:  cats love it
#
#
# Review: boxes crackers tried pretty tasty made gold price
# Original summary: price has to be wrong
# Predicted summary:  crackers
